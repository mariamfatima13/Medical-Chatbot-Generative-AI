# %%
print("Ok")
# Out:
# Ok

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\Medical Chatbot\\Medical-Chatbot-Generative-AI\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\Medical Chatbot\\Medical-Chatbot-Generative-AI'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
def load_pdf_file(data):
    loader = DirectoryLoader(data,
                            glob = "*.pdf",
                            loader_cls = PyPDFLoader)
    documents = loader.load()

    return documents

# %%
# extracted_data = load_pdf_file(data = 'Data/')

# %%
extracted_data = load_pdf_file(data = 'Data/')

# %%
# extracted_data

# %%
#splitting data into text chunks
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
    text_chunks = text_splitter.split_documents(extracted_data)
    return text_chunks

# %%
text_chunks=text_split(extracted_data)
print("length of text chunks", len(text_chunks))
# Out:
# length of text chunks 5859

# %%
# text_chunks

# %%
from langchain.embeddings import HuggingFaceEmbeddings
# Out:
# c:\Users\HP\anaconda3\envs\medibot-genai\lib\importlib\__init__.py:126: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   return _bootstrap._gcd_import(name[level:], package, level)

# %%
# download embeddings from hugging face
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()
print(embeddings.embed_query("this should work!"))
# Out:
# c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\huggingface_hub\file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\huggingface_hub\file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings

def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings

embeddings = download_hugging_face_embeddings()
print(embeddings.embed_query("this should work!")[:5])
# Out:
# [0.009682328440248966, -0.040603723376989365, -0.14084702730178833, -0.011531621217727661, 0.024878717958927155]

# %%
# download embeddings from hugging face
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()

# %%
# pip install ipywidgets
# jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[24], line 1
#     pip install ipywidgets
#         ^
# SyntaxError: invalid syntax

# %%
# import warnings
# warnings.filterwarnings("ignore", category=UserWarning)

# %%
query_result = embeddings.embed_query("hello world")
print("length", len(query_result))
# Out:
# length 384

# %%
# query_result
# Out:
# [-0.034477267414331436,
#  0.031023232266306877,
#  0.006734970025718212,
#  0.02610897459089756,
#  -0.039362017065286636,
#  -0.16030246019363403,
#  0.06692393124103546,
#  -0.006441434845328331,
#  -0.047450464218854904,
#  0.014758843928575516,
#  0.07087533175945282,
#  0.05552758276462555,
#  0.01919332519173622,
#  -0.026251325383782387,
#  -0.010109570808708668,
#  -0.026940444484353065,
#  0.022307386621832848,
#  -0.022226622328162193,
#  -0.149692565202713,
#  -0.017493020743131638,
#  0.007676240522414446,
#  0.054352305829524994,
#  0.003254425246268511,
#  0.03172587230801582,
#  -0.0846213847398758,
#  -0.029405979439616203,
#  0.05159559100866318,
#  0.04812401905655861,
#  -0.003314798464998603,
#  -0.058279190212488174,
#  0.041969288140535355,
#  0.02221061848104,
#  0.12818880379199982,
#  -0.02233891747891903,
#  -0.011656300164759159,
#  0.06292833387851715,
#  -0.03287632018327713,
#  -0.0912260040640831,
#  -0.03117535635828972,
#  0.052699580788612366,
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
PINECONE_API_KEY=os.environ.get('PINECONE_API_KEY')
GEMINI_API_KEY=os.environ.get('GEMINI_API_KEY')
OPENAI_API_KEY=os.environ.get('OPENAI_API_KEY')

# %%
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec
import os

pc = Pinecone(api_key=PINECONE_API_KEY)

index_name = "medicalbot"

pc.create_index(
    name = index_name,
    dimension = 384,
    metric = "cosine",
    spec = ServerlessSpec(
        cloud = "aws",
        region = "us-east-1"
    )
)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[18], line 9
#       5 pc = Pinecone(api_key=PINECONE_API_KEY)
#       7 index_name = "medicalbot"
# ----> 9 pc.create_index(
#      10     name = index_name,
#      11     dimension = 384,
#      12     metric = "cosine",
#      13     spec = ServerlessSpec(
#      14         cloud = "aws",
#      15         region = "us-east-1"
#      16     )
#      17 )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\pinecone\pinecone.py:334, in Pinecone.create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     323 def create_index(
#     324     self,
#     325     name: str,
#    (...)
#     332     tags: Optional[Dict[str, str]] = None,
#     333 ) -> "IndexModel":
# --> 334     return self.db.index.create(
#     335         name=name,
#     336         spec=spec,
# ...

# %%
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print(f"Index '{index_name}' created.")
else:
    print(f"Index '{index_name}' already exists.")
# Out:
# Index 'medicalbot' already exists.

# %%
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec
import os

# Load API key from environment variable
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")  # ✅ Make sure it's set in your environment

# Initialize Pinecone client
pc = Pinecone(api_key=PINECONE_API_KEY)

# Define index parameters
index_name = "medicalbot"

# Create the index (if it doesn't exist)
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print(f"Index '{index_name}' created.")
else:
    print(f"Index '{index_name}' already exists.")
# Out:
# Index 'medicalbot' already exists.

# %%
import os
os.environ["PINECONE_API_KEY"]= PINECONE_API_KEY
os.environ["GEMINI_API_KEY"]= GEMINI_API_KEY
os.environ["OPENAI_API_KEY"]= OPENAI_API_KEY

# %%
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=text_chunks,
    index_name=index_name,
    embedding=embeddings,
)

# %%
# load existing index

from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_existing_index(
    index_name=index_name,
    embedding=embeddings

)

# %%
docsearch

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retrieved_docs = retriever.invoke("what is acne?")

# %%
retrieved_docs
# Out:
# [Document(metadata={'page': 39.0, 'source': 'Data\\Gale Encyclopedia of Medicine Vol. 1 (A-B).pdf'}, page_content='GALE ENCYCLOPEDIA OF MEDICINE 226\nAcne\nGEM - 0001 to 0432 - A  10/22/03 1:41 PM  Page 26'),
#  Document(metadata={'page': 39.0, 'source': 'Data\\Gale Encyclopedia of Medicine Vol. 1 (A-B).pdf'}, page_content='GALE ENCYCLOPEDIA OF MEDICINE 226\nAcne\nGEM - 0001 to 0432 - A  10/22/03 1:41 PM  Page 26'),
#  Document(metadata={'page': 39.0, 'source': 'Data\\Gale Encyclopedia of Medicine Vol. 1 (A-B).pdf'}, page_content='GALE ENCYCLOPEDIA OF MEDICINE 226\nAcne\nGEM - 0001 to 0432 - A  10/22/03 1:41 PM  Page 26')]

# %%
pip install -U langchain-ollama
# Out:
# ...
#
# ...
#
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# ...

# %%
# from langchain_community import Ollama
from langchain_ollama import OllamaLLM
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os

# Load environment variables (if needed)
load_dotenv()

# ✅ 1. Set up your system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

# ✅ 2. Set up prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}")
])

# ✅ 3. Initialize Ollama LLM with Mistral
llm = OllamaLLM(model="mistral")  # You can change to "llama3", "codellama", etc.

# ✅ 4. Initialize retriever (you said you already have this)
# Example:
# from langchain.vectorstores import Pinecone
# from langchain.embeddings import HuggingFaceEmbeddings
# docsearch = Pinecone.from_existing_index("medicalbot", HuggingFaceEmbeddings())
# retriever = docsearch.as_retriever()

# ✅ 5. Create the final RAG chain
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# ✅ 6. Ask your question!
response = rag_chain.invoke({"input": "What is Acne?"})
print("Answer:", response["answer"])
# Out:
# Answer:  According to the provided context, Acne refers to a common skin disorder that occurs when hair follicles become plugged with oil and dead skin cells. This often causes whiteheads, blackheads, or pimples to appear on the face, back, or chest. The condition affects nearly all people at some point in their lives.

# %%
response = rag_chain.invoke({"input": "What is stats?"})
print("Answer:", response["answer"])
# Out:
# Answer:  In the provided context, the term "stats" was not mentioned. A Complete Blood Count (CBC) is a series of tests that provides valuable information about the blood and blood-forming tissues, as well as other body systems. If you were asking about statistics in general, they are numerical data used to make decisions or draw conclusions based on facts and figures. However, without additional context, it's unclear how statistics relate to a Complete Blood Count.

# %%
from langchain_openai import OpenAI
llm = OpenAI(temperature=0.4, max_tokens=500)

# %%
print("Pinecone Key:", PINECONE_API_KEY)
print("Gemini Key:", GEMINI_API_KEY)
print("Openai Key:", OPENAI_API_KEY)
# Out:
# Pinecone Key: pcsk_beYLQ_C7uryFbGjU6NpiFtUffapLxEy5UPXyvrMvJZEdL6UUhurceAwSWP6g5tE81Qo5
# Gemini Key: AIzaSyDzIOnK6yEBprKMiJdDEUPalVCld78XL2o
# Openai Key: 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

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
# from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

# # ✅ Load Gemini API key
# load_dotenv()
# GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# ✅ Define system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

# ✅ Create chat-style prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
]
)

# # ✅ Initialize Gemini LLM
# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.0-flash",  # or "gemini-2.5-pro" if you have access
#     temperature=0.4,
#     max_tokens=500,
#     google_api_key=GEMINI_API_KEY
# )

# ✅ Combine prompt and Gemini LLM
# stuff_chain = create_stuff_documents_chain(llm, prompt)

# 🧠 Later: attach this to your retriever like this:
# final_chain = create_retrieval_chain(retriever, stuff_chain)

# %%
from langchain_community.llms import Ollama

# ✅ Use local Mistral instead of OpenAI/Gemini
llm = Ollama(model="mistral")

# ✅ Re-create your existing chain with the new LLM
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=docsearch.as_retriever(),
    return_source_documents=True
)

response = qa_chain.invoke({"query": "What is Acne?"})
print("Answer:", response["result"])

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

model = genai.GenerativeModel("gemini-1.5-pro")

response = model.generate_content("Explain hypertension to a 12-year-old.")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[29], line 10
#       6 genai.configure(api_key=os.getenv("GEMINI_API_KEY"))
#       8 model = genai.GenerativeModel("gemini-1.5-pro")
# ---> 10 response = model.generate_content("Explain hypertension to a 12-year-old.")
#      11 print(response.text)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
# ...

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv()
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

models = genai.list_models()

for m in models:
    print(m.name, m.supported_generation_methods)
# Out:
# models/embedding-gecko-001 ['embedText', 'countTextTokens']
# models/gemini-1.0-pro-vision-latest ['generateContent', 'countTokens']
# models/gemini-pro-vision ['generateContent', 'countTokens']
# models/gemini-1.5-pro-latest ['generateContent', 'countTokens']
# models/gemini-1.5-pro-002 ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-pro ['generateContent', 'countTokens']
# models/gemini-1.5-flash-latest ['generateContent', 'countTokens']
# models/gemini-1.5-flash ['generateContent', 'countTokens']
# models/gemini-1.5-flash-002 ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-flash-8b ['createCachedContent', 'generateContent', 'countTokens']
# models/gemini-1.5-flash-8b-001 ['createCachedContent', 'generateContent', 'countTokens']
# models/gemini-1.5-flash-8b-latest ['createCachedContent', 'generateContent', 'countTokens']
# ...

# %%
response = model.generate_content(
    "Explain hypertension to a 12-year-old.",
    generation_config=genai.types.GenerationConfig(
        max_output_tokens=500,
        temperature=0.4
    )
)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 response = model.generate_content(
#       2     "Explain hypertension to a 12-year-old.",
#       3     generation_config=genai.types.GenerationConfig(
#       4         max_output_tokens=200,
#       5         temperature=0.5
#       6     )
#       7 )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
# ...

# %%
from langchain_core.documents import Document

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
from google.generativeai.types import GenerationConfig

load_dotenv()
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

model = genai.GenerativeModel("models/gemini-2.0-flash")

response = model.generate_content(
    "Explain hypertension to a 12-year-old.",
    generation_config=GenerationConfig(
        max_output_tokens=500,
        temperature=0.4
    )
)

print(response.text)
# Out:
# Okay, imagine your heart is like a pump that pushes blood through tubes all over your body. These tubes are called blood vessels.
#
# **Hypertension is like having too much pressure in those blood vessels.** Think of it like this:
#
# *   **Normal pressure:** Imagine watering your garden with a hose. You turn on the water and it flows out at a nice, steady pace.
# *   **Hypertension (high blood pressure):** Now imagine someone puts their thumb over the end of the hose. The water still comes out, but it's spraying out harder and faster, putting extra pressure on the hose itself.
#
# That extra pressure in your blood vessels can make your heart work harder. Over a long time, it can also damage your blood vessels, making them weaker or even causing them to break.
#
# **Why is it bad?**
#
# If your blood vessels are damaged, it can lead to serious problems like:
#
# *   **Heart problems:** Your heart has to work harder, which can make it tired and weak.
# ...

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

# ✅ Load Gemini API key
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# ✅ Define system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise.\n\n{context}"
)

# ✅ Create chat-style prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# ✅ Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # or "gemini-2.5-pro" if you have access
    temperature=0.4,
    max_tokens=500,
    google_api_key=GEMINI_API_KEY
)

# ✅ Combine prompt and Gemini LLM
# stuff_chain = create_stuff_documents_chain(llm, prompt)

# 🧠 Later: attach this to your retriever like this:
# final_chain = create_retrieval_chain(retriever, stuff_chain)

# %%
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "what is Acne?"})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 response = rag_chain.invoke({"input": "what is Acne?"})
#       2 print(response["answer"])
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5434, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5427 @override
#    5428 def invoke(
#    5429     self,
#    (...)
#    5432     **kwargs: Optional[Any],
#    5433 ) -> Output:
# -> 5434     return self.bound.invoke(
#    5435         input,
#    5436         self._merge_configs(config),
#    5437         **{**self.kwargs, **kwargs},
#    5438     )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:3046, in RunnableSequence.invoke(self, input, config, **kwargs)
# ...

# %%
response = rag_chain.invoke({"input": "What is Acne?"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 response = rag_chain.invoke({"input": "What is Acne?"})
#       2 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5434, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5427 @override
#    5428 def invoke(
#    5429     self,
#    (...)
#    5432     **kwargs: Optional[Any],
#    5433 ) -> Output:
# -> 5434     return self.bound.invoke(
#    5435         input,
#    5436         self._merge_configs(config),
#    5437         **{**self.kwargs, **kwargs},
#    5438     )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:3046, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044                 input_ = context.run(step.invoke, input_, config, **kwargs)
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.vectorstores import Pinecone
from langchain_community.embeddings import HuggingFaceEmbeddings
from dotenv import load_dotenv
import os
import pinecone

# # Load environment
# load_dotenv()
# GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
# PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
# PINECONE_ENV = "us-east-1"
# INDEX_NAME = "medicalbot"

# # Initialize Pinecone
# pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)
# index = pinecone.Index(INDEX_NAME)

# # Vector store & retriever
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# vectorstore = Pinecone(index, embeddings, namespace="")
# retriever = vectorstore.as_retriever()

# Set up Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=500,
    google_api_key=GEMINI_API_KEY,
    streaming=False
)

# Define custom RAG function (manual flow)
def run_rag(query: str):
    # Retrieve context
    docs = retriever.get_relevant_documents(query)
    context = "\n\n".join([doc.page_content for doc in docs])

    # Create final prompt
    prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer the question. "
        "If you don't know the answer, say that you don't know. "
        "Use three sentences maximum and keep the answer concise.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {query}"
    )

    # Generate answer
    response = llm.invoke(prompt)
    return response.content

# Test the custom RAG chain
print(run_rag("What is Acne?"))
# Out:
# Unexpected argument 'streaming' provided to ChatGoogleGenerativeAI. Did you mean: 'disable_streaming'?
# c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\IPython\core\interactiveshell.py:3579: UserWarning: WARNING! streaming is not default parameter.
#                 streaming was transferred to model_kwargs.
#                 Please confirm that streaming is what you intended.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23064\2019014369.py:37: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(query)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 55
#      52     return response.content
#      54 # Test the custom RAG chain
# ...

# %%
from langchain_core.messages import HumanMessage

def run_rag(query: str):
    # Retrieve context
    docs = retriever.get_relevant_documents(query)
    context = "\n\n".join([doc.page_content for doc in docs])

    # Prompt for Gemini
    prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer the question. "
        "If you don't know the answer, say that you don't know. "
        "Use three sentences maximum and keep the answer concise.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {query}"
    )

    # ✅ Gemini call with code execution explicitly disabled
    response = llm.invoke(HumanMessage(content=prompt), code_execution=False)
    return response.content

# %%
print(run_rag("What is Acne?"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(run_rag("What is Acne?"))
#
# Cell In[42], line 19, in run_rag(query)
#       9 prompt = (
#      10     "You are an assistant for question-answering tasks. "
#      11     "Use the following pieces of retrieved context to answer the question. "
#    (...)
#      15     f"Question: {query}"
#      16 )
#      18 # ✅ Gemini call with code execution explicitly disabled
# ---> 19 response = llm.invoke(HumanMessage(content=prompt), code_execution=False)
#      20 return response.content
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_google_genai\chat_models.py:1255, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1250     else:
#    1251         raise ValueError(
# ...

# %%
from langchain_core.messages import HumanMessage

def run_rag(query: str):
    # Retrieve context
    docs = retriever.get_relevant_documents(query)
    context = "\n\n".join([doc.page_content for doc in docs])

    # Create prompt
    prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer the question. "
        "If you don't know the answer, say that you don't know. "
        "Use three sentences maximum and keep the answer concise.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {query}"
    )

    # ✅ Call LLM with HumanMessage (single message, not a list)
    response = llm.invoke(HumanMessage(content=prompt))
    return response.content

# %%
print(run_rag("What is Acne?"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(run_rag("What is Acne?"))
#
# Cell In[40], line 19, in run_rag(query)
#       9 prompt = (
#      10     "You are an assistant for question-answering tasks. "
#      11     "Use the following pieces of retrieved context to answer the question. "
#    (...)
#      15     f"Question: {query}"
#      16 )
#      18 # ✅ Call LLM with HumanMessage (single message, not a list)
# ---> 19 response = llm.invoke(HumanMessage(content=prompt))
#      20 return response.content
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_google_genai\chat_models.py:1255, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1250     else:
#    1251         raise ValueError(
# ...

# %%
response = rag_chain.invoke({"input": "what is acne?"})
print(response.get("answer", "No answer found"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 response = rag_chain.invoke({"input": "what is acne?"})
#       2 print(response.get("answer", "No answer found"))
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
import os
from dotenv import load_dotenv
import time

# 1. Load environment
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# 2. Current working model names (June 2024)
WORKING_MODELS = {
    "free": "gemini-pro",  # Basic free tier
    "paid": "gemini-1.5-pro-latest"  # Requires billing
}

# 3. Initialize LLM with automatic fallback
try:
    llm = ChatGoogleGenerativeAI(
        model=WORKING_MODELS["free"],
        temperature=0.4,
        max_output_tokens=200,  # Keep responses short
        google_api_key=GEMINI_API_KEY
    )
    # Test the connection
    llm.invoke("test")  # This will fail immediately if model is wrong
except Exception as e:
    print(f"Model error: {str(e)[:200]}... Falling back to direct API calls")
    from google.generativeai import configure, GenerativeModel
    configure(api_key=GEMINI_API_KEY)
    llm = GenerativeModel('gemini-pro')

# 4. Simplified prompt template
prompt = ChatPromptTemplate.from_template("""
Answer in 1-2 sentences using this context:
{context}

Question: {input}
If you don't know, say "I don't have enough information".
""")

# 5. Create chains
document_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, document_chain)

# 6. Safe execution with retries
def get_answer(question, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = rag_chain.invoke({"input": question})
            return response.get("answer", "No answer found")
        except Exception as e:
            if "quota" in str(e).lower():
                wait = min(60, (attempt + 1) * 10)  # Max 60 second wait
                print(f"Rate limited. Waiting {wait} seconds...")
                time.sleep(wait)
            else:
                print(f"Attempt {attempt + 1} failed: {str(e)[:200]}...")
                if attempt == max_retries - 1:
                    # Final fallback to direct question answering
                    return llm.invoke(question).content

# 7. Run with error handling
try:
    answer = get_answer("what is acne?")
    print("Answer:", answer)
except Exception as e:
    print("Complete failure:", str(e)[:200])
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Model error: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.... Falling back to direct API calls
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 45
#      36 prompt = ChatPromptTemplate.from_template("""
#      37 Answer in 1-2 sentences using this context:
#      38 {context}
#    (...)
#      41 If you don't know, say "I don't have enough information".
#      42 """)
#      44 # 5. Create chains
# ...

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.runnables import RunnableLambda
import os
from dotenv import load_dotenv

# Load Gemini API key
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Define system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise.\n\n{context}"
)

# Create chat-style prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Changed to a valid model (see note below)
    temperature=0.4,
    max_tokens=500,
    google_api_key=GEMINI_API_KEY
)

# Custom output parser to handle unexpected 'thought' field
def parse_response(response):
    if isinstance(response, dict):
        # Remove 'thought' field if present
        if "thought" in response:
            del response["thought"]
        return response.get("answer", response.get("content", "No answer found"))
    return response.content if hasattr(response, "content") else str(response)

# Combine prompt and Gemini LLM with the custom parser
stuff_chain = create_stuff_documents_chain(llm, prompt)
question_answer_chain = create_stuff_documents_chain(llm, prompt)

# Wrap the retrieval chain with the custom parser
rag_chain = create_retrieval_chain(retriever, question_answer_chain) | RunnableLambda(parse_response)

# Invoke the chain
try:
    response = rag_chain.invoke({"input": "what is acne?"})
    print(response)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Error: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
import time

# Load API key
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Correct model names as of June 2024
AVAILABLE_MODELS = {
    "free": "gemini-2.0-flash",  # Basic free tier model
    "paid": "gemini-1.5-pro-latest"  # Requires billing
}

# Initialize with free model first
llm = ChatGoogleGenerativeAI(
    model=AVAILABLE_MODELS["free"],
    temperature=0.4,
    max_output_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# Simple retry mechanism
def query_with_retry(chain, question, max_retries=3):
    for attempt in range(max_retries):
        try:
            return chain.invoke({"input": question})
        except Exception as e:
            if "quota" in str(e).lower():
                wait_time = (attempt + 1) * 5  # Exponential backoff
                print(f"Rate limited. Waiting {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                raise e
    raise Exception(f"Failed after {max_retries} retries")

# Your existing RAG setup
system_prompt = """Answer concisely using this context:
{context}"""
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])
document_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, document_chain)

try:
    response = query_with_retry(rag_chain, "what is acne?")
    print(response["answer"])
except Exception as e:
    print(f"Error: {e}")
    print("Trying fallback to direct question answering...")
    # Fallback without retriever
    fallback_chain = prompt | llm
    print(fallback_chain.invoke({"input": "what is acne?", "context": ""}))
# Out:
# Error: Unknown field for Part: thought
# Trying fallback to direct question answering...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 52
#      51 try:
# ---> 52     response = query_with_retry(rag_chain, "what is acne?")
#      53     print(response["answer"])
#
# Cell In[57], line 38, in query_with_retry(chain, question, max_retries)
#      37         else:
# ---> 38             raise e
#      39 raise Exception(f"Failed after {max_retries} retries")
#
# Cell In[57], line 31, in query_with_retry(chain, question, max_retries)
#      30 try:
# ---> 31     return chain.invoke({"input": question})
#      32 except Exception as e:
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
# ...

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

# ✅ Load Gemini API key
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# ✅ Define system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise.\n\n{context}"
)

# ✅ Create chat-style prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# ✅ Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # or "gemini-2.5-pro" if you have access
    temperature=0.4,
    max_tokens=500,
    google_api_key=GEMINI_API_KEY
)

# ✅ Combine prompt and Gemini LLM
question_answer_chain = create_stuff_documents_chain(llm, prompt)

# Assuming you've already defined your retriever like this:
# retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# Create the retrieval chain
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# Now you can invoke it
response = rag_chain.invoke({"input": "what is acne?"})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 45
#      42 rag_chain = create_retrieval_chain(retriever, question_answer_chain)
#      44 # Now you can invoke it
# ---> 45 response = rag_chain.invoke({"input": "what is acne?"})
#      46 print(response["answer"])
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# ...

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

# Load Gemini API key
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Define system prompt
system_prompt = """You are a helpful AI assistant. Answer the question based on the context below.
If you don't know the answer, say you don't know. Keep it concise.

Context: {context}"""

# Create chat prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Updated model name
    temperature=0.4,
    google_api_key=GEMINI_API_KEY
)

# Create document chain
document_chain = create_stuff_documents_chain(llm, prompt)

# Make sure your retriever is properly initialized
# retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# Create retrieval chain
rag_chain = create_retrieval_chain(retriever, document_chain)

# Invoke the chain with proper input format
try:
    response = rag_chain.invoke({"input": "what is acne?"})
    print(response["answer"])
except Exception as e:
    print(f"Error: {e}")
    print("Please check your retriever implementation.")
# Out:
# Error: Unknown field for Part: thought
# Please check your retriever implementation.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain

from langchain.vectorstores import FAISS
from langchain_google_genai import GoogleGenerativeAIEmbeddings

from langchain_core.documents import Document
from dotenv import load_dotenv
import os

# ✅ Load .env and keys
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# ✅ Set up LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY,
)

# ✅ Prompt Template — use `documents` key here
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful medical assistant. Use the below context to answer:\n\n{documents}"),
    ("user", "{input}")
])

# ✅ Combine LLM + prompt
qa_chain = create_stuff_documents_chain(llm, prompt)

# ✅ Load FAISS retriever
embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-gecko-001", google_api_key=GEMINI_API_KEY)
vectorstore = FAISS.load_local("faiss_index", embedding, allow_dangerous_deserialization=True)
retriever = vectorstore.as_retriever()

# ✅ Manual retrieval + answer
query = "What is acne?"
docs = retriever.invoke(query)

# ✅ Run LLM on docs
response = qa_chain.invoke({
    "input": query,
    "documents": docs
})

# ✅ Show result
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 31
#      25 prompt = ChatPromptTemplate.from_messages([
#      26     ("system", "You are a helpful medical assistant. Use the below context to answer:\n\n{documents}"),
#      27     ("user", "{input}")
#      28 ])
#      30 # ✅ Combine LLM + prompt
# ---> 31 qa_chain = create_stuff_documents_chain(llm, prompt)
#      33 # ✅ Load FAISS retriever
#      34 embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-gecko-001", google_api_key=GEMINI_API_KEY)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain\chains\combine_documents\stuff.py:79, in create_stuff_documents_chain(llm, prompt, output_parser, document_prompt, document_separator, document_variable_name)
#      24 def create_stuff_documents_chain(
#      25     llm: LanguageModelLike,
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer the question. "
    "If you don't know the answer, say you don't know. Keep answers concise (max 3 sentences).\n\n{context}"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", "{input}"),
])

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Setup Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Less quota usage
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# Prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the retrieved context to answer the question. "
    "If unsure, say you don't know. Be concise.\n\n{context}"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", "{input}"),
])

# Create chain
question_answer_chain = create_stuff_documents_chain(llm, prompt)

# Plug in your retriever
# retriever = FAISS.load_local("faiss_index", embeddings).as_retriever()
# rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# Example to test:
# response = rag_chain.invoke({"input": "What is acne?"})
# print(response["answer"])

# %%
response = rag_chain.invoke({"input": "what is acne?"})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 response = rag_chain.invoke({"input": "what is acne?"})
#       2 print(response["answer"])
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful medical assistant. Use the context to answer.\n\n{context}"),
    ("user", "{input}"),
])

# %%
[
    Document(page_content="Acne is a skin condition..."),
    Document(page_content="It usually occurs when..."),
]
# Out:
# [Document(metadata={}, page_content='Acne is a skin condition...'),
#  Document(metadata={}, page_content='It usually occurs when...')]

# %%
docs = retriever.get_relevant_documents("what is acne?")
print(docs[0].page_content)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10392\1323533307.py:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents("what is acne?")
# GALE ENCYCLOPEDIA OF MEDICINE 226
# Acne
# GEM - 0001 to 0432 - A  10/22/03 1:41 PM  Page 26

# %%
from langchain_core.documents import Document

fake_docs = [Document(page_content="Acne is a skin condition that occurs when hair follicles become clogged.")]

response = question_answer_chain.invoke({
    "input": "what is acne?",
    "context": fake_docs
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 5
#       1 from langchain_core.documents import Document
#       3 fake_docs = [Document(page_content="Acne is a skin condition that occurs when hair follicles become clogged.")]
# ----> 5 response = question_answer_chain.invoke({
#       6     "input": "what is acne?",
#       7     "context": fake_docs
#       8 })
#      10 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
# ...

# %%
response = rag_chain.invoke({"input": "what is acne?"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 response = rag_chain.invoke({"input": "what is acne?"})
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# Prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{context}"),
    ("user", "{input}")
])

# Chain
stuff_chain = create_stuff_documents_chain(llm, prompt)

# Documents
docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

# ✅ Correct invocation — pass both input + docs in a single dict
response = stuff_chain.invoke({
    "input": "What is acne?",
    "documents": docs
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 36
#      30 docs = [
#      31     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      32     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      33 ]
#      35 # ✅ Correct invocation — pass both input + docs in a single dict
# ---> 36 response = stuff_chain.invoke({
#      37     "input": "What is acne?",
#      38     "documents": docs
#      39 })
#      41 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

load_dotenv()
llm = ChatGoogleGenerativeAI(
   model="gemini-1.5-flash",
   temperature=0.4,
   google_api_key=os.getenv("GEMINI_API_KEY")
)

prompt = ChatPromptTemplate.from_messages([
   ("system", "You are a helpful assistant. Use the context below:\n\n{context}"),
   ("user", "{input}")
])

chain = create_stuff_documents_chain(llm=llm, prompt=prompt)

docs = [
   Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
   Document(page_content="It causes pimples, blackheads, and whiteheads.")
]

# ✅ Use run() instead of invoke()
response = chain.run(documents=docs, input="What is acne?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 28
#      22 docs = [
#      23    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      24    Document(page_content="It causes pimples, blackheads, and whiteheads.")
#      25 ]
#      27 # ✅ Use run() instead of invoke()
# ---> 28 response = chain.run(documents=docs, input="What is acne?")
#      29 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5834, in RunnableBinding.__getattr__(self, name)
#    5832 @override
#    5833 def __getattr__(self, name: str) -> Any:  # type: ignore[misc]
# -> 5834     attr = getattr(self.bound, name)
#    5836     if callable(attr) and (
#    5837         config_param := inspect.signature(attr).parameters.get("config")
#    5838     ):
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Gemini LLM (chat model)
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",  # use "gemini-1.5-flash" or "gemini-pro" if "2.0" breaks
    temperature=0.4,
    google_api_key=GEMINI_API_KEY
)

# Prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{context}"),
    ("user", "{input}")
])

# Chain using 'context' as document variable name
stuff_chain = create_stuff_documents_chain(llm=llm, prompt=prompt)

# Example documents
docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

# ✅ Use `context` as expected by the prompt
response = stuff_chain.invoke({
    "input": "What is acne?",
    "context": docs
})

print(response.content)  # 👈 Use .content to extract text from response
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 35
#      29 docs = [
#      30     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      31     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      32 ]
#      34 # ✅ Use `context` as expected by the prompt
# ---> 35 response = stuff_chain.invoke({
#      36     "input": "What is acne?",
#      37     "context": docs
#      38 })
#      40 print(response.content)  # 👈 Use .content to extract text from response
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# Prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{context}"),
    ("user", "{input}")
])

# Chain
stuff_chain = create_stuff_documents_chain(llm, prompt)

# Documents
docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

# ✅ Correct usage: use "context" as the key
response = stuff_chain.invoke({
    "input": "What is acne?",
    "context": docs
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 36
#      30 docs = [
#      31     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      32     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      33 ]
#      35 # ✅ Correct usage: use "context" as the key
# ---> 36 response = stuff_chain.invoke({
#      37     "input": "What is acne?",
#      38     "context": docs
#      39 })
#      41 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# ✅ FIXED Prompt – use {documents}
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{documents}"),
    ("user", "{input}")
])

# Chain
stuff_chain = create_stuff_documents_chain(llm, prompt)

# Documents
docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

# ✅ Correct invocation — keys match template
response = stuff_chain.invoke({
    "input": "What is acne?",
    "documents": docs
})

# Output
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 27
#      21 prompt = ChatPromptTemplate.from_messages([
#      22     ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{documents}"),
#      23     ("user", "{input}")
#      24 ])
#      26 # Chain
# ---> 27 stuff_chain = create_stuff_documents_chain(llm, prompt)
#      29 # Documents
#      30 docs = [
#      31     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      32     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      33 ]
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain\chains\combine_documents\stuff.py:79, in create_stuff_documents_chain(llm, prompt, output_parser, document_prompt, document_separator, document_variable_name)
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents.stuff import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{documents}"),
    ("user", "{input}")
])

stuff_chain = create_stuff_documents_chain(llm, prompt)

docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

response = stuff_chain.invoke({
    "input": "What is acne?",
    "documents": docs
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 23
#      11 llm = ChatGoogleGenerativeAI(
#      12     model="gemini-2.0-flash",
#      13     temperature=0.4,
#      14     max_tokens=300,
#      15     google_api_key=GEMINI_API_KEY
#      16 )
#      18 prompt = ChatPromptTemplate.from_messages([
#      19     ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{documents}"),
#      20     ("user", "{input}")
#      21 ])
# ---> 23 stuff_chain = create_stuff_documents_chain(llm, prompt)
#      25 docs = [
#      26     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      27     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      28 ]
#      30 response = stuff_chain.invoke({
#      31     "input": "What is acne?",
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.combine_documents.stuff import create_stuff_documents_chain
from langchain_core.documents import Document
from dotenv import load_dotenv
import os

load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.4,
    max_tokens=300,
    google_api_key=GEMINI_API_KEY
)

# Key change: Use "context" instead of "documents" to match expected variable name
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Use the context below to answer the question:\n\n{context}"),
    ("user", "{input}")
])

stuff_chain = create_stuff_documents_chain(llm, prompt)

docs = [
    Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
    Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
]

response = stuff_chain.invoke({
    "input": "What is acne?",
    "context": docs  # Changed from "documents" to "context"
})

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 31
#      24 stuff_chain = create_stuff_documents_chain(llm, prompt)
#      26 docs = [
#      27     Document(page_content="Acne is a skin condition caused by clogged hair follicles."),
#      28     Document(page_content="It causes pimples, blackheads, and whiteheads, especially in teenagers.")
#      29 ]
# ---> 31 response = stuff_chain.invoke({
#      32     "input": "What is acne?",
#      33     "context": docs  # Changed from "documents" to "context"
#      34 })
#      36 print(response)
#
# File c:\Users\HP\anaconda3\envs\medibot-genai\lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# ...
